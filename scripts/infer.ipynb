# %%
# === Jupyter-friendly inference (infer.py) =========================
import json
from pathlib import Path
from PIL import Image
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms as T

# ---- config ----
CKPT_DIR = Path("checkpoints_multiclass_strong")   # where best.pt lives
DATA_DIR = Path("disaster-ai/data/xbd/tier1")      # used if you pass relative paths

# ---- model builders ----
def build_model(backbone: str, n_classes: int):
    if backbone == "resnet18":
        m = torchvision.models.resnet18(weights=None)
        m.fc = nn.Linear(m.fc.in_features, n_classes)
    elif backbone == "resnet50":
        m = torchvision.models.resnet50(weights=None)
        m.fc = nn.Linear(m.fc.in_features, n_classes)
    elif backbone == "efficientnet_b0":
        m = torchvision.models.efficientnet_b0(weights=None)
        m.classifier[1] = nn.Linear(m.classifier[1].in_features, n_classes)
    elif backbone == "vit_b_16":
        m = torchvision.models.vit_b_16(weights=None)
        m.heads.head = nn.Linear(m.heads.head.in_features, n_classes)
    else:
        raise ValueError(f"Unknown backbone: {backbone}")
    return m

def load_pipeline(ckpt_dir: Path = CKPT_DIR):
    """Load best.pt and return (model, transform, classes)."""
    ckpt_path = ckpt_dir / "best.pt"
    if not ckpt_path.exists():
        raise FileNotFoundError(f"Checkpoint not found: {ckpt_path}")
    ckpt = torch.load(ckpt_path, map_location="cpu")

    classes  = ckpt["classes"]
    img_size = ckpt["img_size"]
    backbone = ckpt["backbone"]

    model = build_model(backbone, len(classes))
    model.load_state_dict(ckpt["model_state"])
    model.eval()

    tform = T.Compose([
        T.Resize(int(img_size * 1.2)),
        T.CenterCrop(img_size),
        T.ToTensor(),
        T.Normalize([0.485,0.456,0.406], [0.229,0.224,0.225]),
    ])
    return model, tform, classes

# ---- prediction helpers ----
def predict_one(model, tform, classes, path: Path):
    img = Image.open(path).convert("RGB")
    x = tform(img).unsqueeze(0)
    with torch.no_grad():
        logits = model(x)
        probs = torch.softmax(logits, dim=1).squeeze(0)
        top = probs.argmax().item()
    return classes[top], float(probs[top])

def run_inference(image_paths, return_json=False, quiet=False):
    """
    image_paths: list[str|Path] or a single str/Path
    return_json: if True returns JSON string; else returns list of dicts
    quiet:       if False prints one-line summary per image
    """
    if isinstance(image_paths, (str, Path)):
        image_paths = [image_paths]

    model, tform, classes = load_pipeline()

    outputs = []
    for p in image_paths:
        path = Path(p)
        if not path.is_file():
            # allow relative paths like "images/foo.png"
            path = DATA_DIR / p
        if not path.is_file():
            raise FileNotFoundError(f"Image not found: {p} (also tried {path})")

        label, conf = predict_one(model, tform, classes, path)
        rec = {"image_path": str(path), "pred": label, "conf": round(conf, 4)}
        outputs.append(rec)
        if not quiet:
            print(f"{path.name:45s} -> {label:13s} (conf={conf:.2f})")

    if return_json:
        return json.dumps(outputs, indent=2)
    return outputs
# ==================================================================

# %%
# Single image
run_inference("images/socal-fire_00001323_post_disaster.png")

# Multiple images
imgs = [
    "images/palu-tsunami_00000125_post_disaster.png",
    "images/socal-fire_00001333_post_disaster.png",
]
preds = run_inference(imgs)

# If you prefer JSON output (e.g., to save or send somewhere)
json_str = run_inference(imgs, return_json=True, quiet=True)
print(json_str)
# Out:
# socal-fire_00001323_post_disaster.png         -> destroyed     (conf=0.96)
# palu-tsunami_00000125_post_disaster.png       -> no-damage     (conf=1.00)
# socal-fire_00001333_post_disaster.png         -> no-damage     (conf=1.00)
# [
#   {
#     "image_path": "disaster-ai/data/xbd/tier1/images/palu-tsunami_00000125_post_disaster.png",
#     "pred": "no-damage",
#     "conf": 0.9997
#   },
#   {
#     "image_path": "disaster-ai/data/xbd/tier1/images/socal-fire_00001333_post_disaster.png",
#     "pred": "no-damage",
#     "conf": 0.9997
#   }
# ]

# %%
# --- Batch prediction -> CSV ---------------------------------------------------
from pathlib import Path
import pandas as pd

SUPPORTED_EXTS = (".png", ".jpg", ".jpeg", ".tif", ".tiff", ".bmp")

def batch_predict_to_csv(
    image_dir="disaster-ai/data/xbd/tier1/images",
    out_csv="batch_predictions.csv",
    recursive=True,
    quiet=False,
):
    """
    Scan image_dir for images, run inference with the trained checkpoint,
    and save predictions to a CSV with columns: image_path, pred, conf [, error].
    """
    image_dir = Path(image_dir)
    assert image_dir.exists(), f"Directory not found: {image_dir}"

    # Collect paths
    if recursive:
        candidates = image_dir.rglob("*")
    else:
        candidates = image_dir.glob("*")
    paths = [p for p in candidates if p.suffix.lower() in SUPPORTED_EXTS]
    paths = sorted(paths)
    if not paths:
        print(f"No images found in {image_dir} (recursive={recursive}).")
        return []

    # Load your trained pipeline (uses the helpers you already have)
    model, tform, classes = load_pipeline()  # from your earlier cell
    recs = []

    for p in paths:
        try:
            label, conf = predict_one(model, tform, classes, p)  # from your earlier cell
            rec = {"image_path": str(p), "pred": label, "conf": round(conf, 4)}
            if not quiet:
                print(f"{p.name:45s} -> {label:13s} (conf={conf:.2f})")
        except Exception as e:
            # keep going even if one image fails
            rec = {"image_path": str(p), "pred": None, "conf": None, "error": str(e)}
            if not quiet:
                print(f"⚠️  {p.name}: {e}")
        recs.append(rec)

    pd.DataFrame(recs).to_csv(out_csv, index=False)
    ok = sum(1 for r in recs if r["pred"] is not None)
    print(f"✅ Saved {ok}/{len(recs)} predictions to {out_csv}")
    return recs
# ------------------------------------------------------------------------------

# %%
# default: your dataset images folder, recursive, prints progress
batch_predict_to_csv()

# custom folder + quiet mode
batch_predict_to_csv("some/other/folder", out_csv="preds_other.csv", recursive=True, quiet=True)
# Out:
# guatemala-volcano_00000000_post_disaster.png  -> no-damage     (conf=0.98)
# guatemala-volcano_00000000_pre_disaster.png   -> no-damage     (conf=0.99)
# guatemala-volcano_00000001_post_disaster.png  -> minor-damage  (conf=1.00)
# guatemala-volcano_00000001_pre_disaster.png   -> minor-damage  (conf=0.91)
# guatemala-volcano_00000002_post_disaster.png  -> destroyed     (conf=0.91)
# guatemala-volcano_00000002_pre_disaster.png   -> no-damage     (conf=0.91)
# guatemala-volcano_00000006_post_disaster.png  -> no-damage     (conf=1.00)
# guatemala-volcano_00000006_pre_disaster.png   -> no-damage     (conf=1.00)
# guatemala-volcano_00000007_post_disaster.png  -> no-damage     (conf=0.99)
# guatemala-volcano_00000007_pre_disaster.png   -> no-damage     (conf=1.00)
# guatemala-volcano_00000008_pre_disaster.png   -> no-damage     (conf=0.62)
# guatemala-volcano_00000010_post_disaster.png  -> destroyed     (conf=1.00)
# guatemala-volcano_00000013_post_disaster.png  -> no-damage     (conf=1.00)
# guatemala-volcano_00000013_pre_disaster.png   -> no-damage     (conf=1.00)
# guatemala-volcano_00000015_post_disaster.png  -> no-damage     (conf=1.00)
# guatemala-volcano_00000015_pre_disaster.png   -> no-damage     (conf=0.98)
# guatemala-volcano_00000016_post_disaster.png  -> minor-damage  (conf=1.00)
# guatemala-volcano_00000016_pre_disaster.png   -> minor-damage  (conf=0.99)
# guatemala-volcano_00000017_post_disaster.png  -> no-damage     (conf=1.00)
# guatemala-volcano_00000017_pre_disaster.png   -> no-damage     (conf=1.00)
# guatemala-volcano_00000018_post_disaster.png  -> no-damage     (conf=0.99)
# guatemala-volcano_00000018_pre_disaster.png   -> no-damage     (conf=0.87)
# guatemala-volcano_00000019_post_disaster.png  -> no-damage     (conf=1.00)
# guatemala-volcano_00000019_pre_disaster.png   -> no-damage     (conf=1.00)
# guatemala-volcano_00000023_post_disaster.png  -> no-damage     (conf=0.99)
# guatemala-volcano_00000023_pre_disaster.png   -> no-damage     (conf=0.86)
# guatemala-volcano_00000024_post_disaster.png  -> no-damage     (conf=0.89)
# guatemala-volcano_00000024_pre_disaster.png   -> no-damage     (conf=1.00)
# guatemala-volcano_00000025_post_disaster.png  -> destroyed     (conf=1.00)
# guatemala-volcano_00000025_pre_disaster.png   -> no-damage     (conf=0.94)
# guatemala-volcano_00000026_post_disaster.png  -> no-damage     (conf=1.00)
# guatemala-volcano_00000026_pre_disaster.png   -> no-damage     (conf=1.00)
# guatemala-volcano_00000027_post_disaster.png  -> no-damage     (conf=1.00)
# guatemala-volcano_00000027_pre_disaster.png   -> no-damage     (conf=1.00)
# hurricane-florence_00000000_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000000_pre_disaster.png  -> no-damage     (conf=0.93)
# hurricane-florence_00000001_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000002_pre_disaster.png  -> destroyed     (conf=0.41)
# hurricane-florence_00000003_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000003_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000008_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000008_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000012_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000012_pre_disaster.png  -> no-damage     (conf=0.97)
# hurricane-florence_00000015_post_disaster.png -> no-damage     (conf=0.99)
# hurricane-florence_00000015_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000016_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000016_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000018_post_disaster.png -> destroyed     (conf=0.79)
# hurricane-florence_00000018_pre_disaster.png  -> no-damage     (conf=0.98)
# hurricane-florence_00000020_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000020_pre_disaster.png  -> no-damage     (conf=0.92)
# hurricane-florence_00000022_post_disaster.png -> major-damage  (conf=0.98)
# hurricane-florence_00000022_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000023_post_disaster.png -> no-damage     (conf=0.98)
# hurricane-florence_00000023_pre_disaster.png  -> no-damage     (conf=0.72)
# hurricane-florence_00000024_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000024_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000026_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000026_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000027_post_disaster.png -> no-damage     (conf=0.61)
# hurricane-florence_00000027_pre_disaster.png  -> destroyed     (conf=0.49)
# hurricane-florence_00000028_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000028_pre_disaster.png  -> no-damage     (conf=0.88)
# hurricane-florence_00000030_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000030_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000031_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000031_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000032_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000032_pre_disaster.png  -> no-damage     (conf=0.99)
# hurricane-florence_00000036_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000036_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00
post_disaster.png -> major-damage  (conf=1.00)
# hurricane-florence_00000482_pre_disaster.png  -> no-damage     (conf=0.98)
# hurricane-florence_00000484_post_disaster.png -> major-damage  (conf=1.00)
# hurricane-florence_00000484_pre_disaster.png  -> no-damage     (conf=0.99)
# hurricane-florence_00000485_post_disaster.png -> major-damage  (conf=0.93)
# hurricane-florence_00000485_pre_disaster.png  -> no-damage     (conf=0.98)
# hurricane-florence_00000486_post_disaster.png -> no-damage     (conf=0.90)
# hurricane-florence_00000486_pre_disaster.png  -> no-damage     (conf=0.50)
# hurricane-florence_00000490_post_disaster.png -> major-damage  (conf=1.00)
# hurricane-florence_00000490_pre_disaster.png  -> no-damage     (conf=0.98)
# hurricane-florence_00000492_post_disaster.png -> major-damage  (conf=0.97)
# hurricane-florence_00000492_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000493_post_disaster.png -> major-damage  (conf=0.90)
# hurricane-florence_00000493_pre_disaster.png  -> major-damage  (conf=0.72)
# hurricane-florence_00000494_post_disaster.png -> major-damage  (conf=0.99)
# hurricane-florence_00000494_pre_disaster.png  -> no-damage     (conf=0.72)
# hurricane-florence_00000496_post_disaster.png -> major-damage  (conf=0.99)
# hurricane-florence_00000496_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000497_post_disaster.png -> no-damage     (conf=0.97)
# hurricane-florence_00000497_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000498_post_disaster.png -> major-damage  (conf=0.97)
# hurricane-florence_00000498_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000500_post_disaster.png -> major-damage  (conf=0.99)
# hurricane-florence_00000500_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000501_post_disaster.png -> major-damage  (conf=0.99)
# hurricane-florence_00000501_pre_disaster.png  -> major-damage  (conf=0.95)
# hurricane-florence_00000503_post_disaster.png -> major-damage  (conf=0.97)
# hurricane-florence_00000503_pre_disaster.png  -> no-damage     (conf=0.57)
# hurricane-florence_00000504_post_disaster.png -> major-damage  (conf=1.00)
# hurricane-florence_00000504_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000506_post_disaster.png -> major-damage  (conf=0.96)
# hurricane-florence_00000506_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000508_post_disaster.png -> destroyed     (conf=1.00)
# hurricane-florence_00000508_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000510_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000510_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000512_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000512_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000513_post_disaster.png -> major-damage  (conf=0.98)
# hurricane-florence_00000513_pre_disaster.png  -> no-damage     (conf=1.00)
# hurricane-florence_00000514_post_disaster.png -> major-damage  (conf=0.94)
# hurricane-florence_00000514_pre_disaster.png  -> no-damage     (conf=0.99)
# hurricane-florence_00000515_post_disaster.png -> no-damage     (conf=1.00)
# hurricane-florence_00000515_pre_disaster.png  -> minor-damage  (conf=0.77)
# ...
# socal-fire_00001256_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001257_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001257_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001258_post_disaster.png         -> no-damage     (conf=0.94)
# socal-fire_00001258_pre_disaster.png          -> no-damage     (conf=0.77)
# socal-fire_00001259_post_disaster.png         -> destroyed     (conf=1.00)
# socal-fire_00001259_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001260_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001260_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001261_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001261_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001263_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001263_pre_disaster.png          -> no-damage     (conf=0.62)
# socal-fire_00001264_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001264_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001268_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001268_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001269_post_disaster.png         -> no-damage     (conf=0.81)
# socal-fire_00001269_pre_disaster.png          -> no-damage     (conf=0.99)
# socal-fire_00001270_post_disaster.png         -> no-damage     (conf=0.96)
# socal-fire_00001270_pre_disaster.png          -> no-damage     (conf=0.54)
# socal-fire_00001271_post_disaster.png         -> no-damage     (conf=0.96)
# socal-fire_00001271_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001272_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001272_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001274_post_disaster.png         -> no-damage     (conf=0.98)
# socal-fire_00001274_pre_disaster.png          -> no-damage     (conf=0.99)
# socal-fire_00001275_post_disaster.png         -> destroyed     (conf=0.83)
# socal-fire_00001275_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001278_post_disaster.png         -> destroyed     (conf=0.99)
# socal-fire_00001278_pre_disaster.png          -> no-damage     (conf=0.70)
# socal-fire_00001282_post_disaster.png         -> destroyed     (conf=0.38)
# socal-fire_00001282_pre_disaster.png          -> destroyed     (conf=0.79)
# socal-fire_00001283_post_disaster.png         -> no-damage     (conf=0.95)
# socal-fire_00001283_pre_disaster.png          -> no-damage     (conf=0.94)
# socal-fire_00001285_post_disaster.png         -> destroyed     (conf=0.99)
# socal-fire_00001285_pre_disaster.png          -> no-damage     (conf=0.99)
# socal-fire_00001286_post_disaster.png         -> destroyed     (conf=0.96)
# socal-fire_00001286_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001287_post_disaster.png         -> no-damage     (conf=0.77)
# socal-fire_00001287_pre_disaster.png          -> no-damage     (conf=0.97)
# socal-fire_00001288_post_disaster.png         -> no-damage     (conf=0.50)
# socal-fire_00001288_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001289_post_disaster.png         -> no-damage     (conf=0.94)
# socal-fire_00001289_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001291_post_disaster.png         -> destroyed     (conf=1.00)
# socal-fire_00001291_pre_disaster.png          -> no-damage     (conf=0.95)
# socal-fire_00001292_post_disaster.png         -> no-damage     (conf=0.99)
# socal-fire_00001292_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001293_post_disaster.png         -> no-damage     (conf=0.79)
# socal-fire_00001293_pre_disaster.png          -> no-damage     (conf=0.89)
# socal-fire_00001296_post_disaster.png         -> destroyed     (conf=0.96)
# socal-fire_00001296_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001297_post_disaster.png         -> no-damage     (conf=0.94)
# socal-fire_00001297_pre_disaster.png          -> no-damage     (conf=0.99)
# socal-fire_00001298_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001298_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001300_post_disaster.png         -> destroyed     (conf=0.71)
# socal-fire_00001300_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001301_post_disaster.png         -> no-damage     (conf=0.68)
# socal-fire_00001301_pre_disaster.png          -> no-damage     (conf=0.86)
# socal-fire_00001302_post_disaster.png         -> no-damage     (conf=0.97)
# socal-fire_00001302_pre_disaster.png          -> no-damage     (conf=0.96)
# socal-fire_00001303_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001303_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001304_post_disaster.png         -> destroyed     (conf=0.96)
# socal-fire_00001304_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001307_post_disaster.png         -> destroyed     (conf=0.67)
# socal-fire_00001307_pre_disaster.png          -> destroyed     (conf=0.87)
# socal-fire_00001308_post_disaster.png         -> no-damage     (conf=0.99)
# socal-fire_00001308_pre_disaster.png          -> no-damage     (conf=0.86)
# socal-fire_00001312_post_disaster.png         -> destroyed     (conf=1.00)
# socal-fire_00001312_pre_disaster.png          -> destroyed     (conf=0.99)
# socal-fire_00001313_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001313_pre_disaster.png          -> no-damage     (conf=0.99)
# socal-fire_00001315_post_disaster.png         -> no-damage     (conf=0.84)
# socal-fire_00001315_pre_disaster.png          -> no-damage     (conf=0.90)
# socal-fire_00001317_post_disaster.png         -> no-damage     (conf=0.75)
# socal-fire_00001317_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001318_post_disaster.png         -> no-damage     (conf=0.66)
# socal-fire_00001318_pre_disaster.png          -> no-damage     (conf=0.95)
# socal-fire_00001319_post_disaster.png         -> destroyed     (conf=0.99)
# socal-fire_00001319_pre_disaster.png          -> no-damage     (conf=0.99)
# socal-fire_00001320_post_disaster.png         -> destroyed     (conf=0.69)
# socal-fire_00001320_pre_disaster.png          -> no-damage     (conf=0.99)
# socal-fire_00001322_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001322_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001323_post_disaster.png         -> destroyed     (conf=0.96)
# socal-fire_00001323_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001324_post_disaster.png         -> no-damage     (conf=0.99)
# socal-fire_00001324_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001325_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001325_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001330_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001330_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001331_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001331_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001333_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001333_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001334_post_disaster.png         -> destroyed     (conf=1.00)
# socal-fire_00001334_pre_disaster.png          -> no-damage     (conf=0.99)
# socal-fire_00001337_post_disaster.png         -> no-damage     (conf=0.89)
# socal-fire_00001337_pre_disaster.png          -> no-damage     (conf=0.96)
# socal-fire_00001338_post_disaster.png         -> destroyed     (conf=0.94)
# socal-fire_00001338_pre_disaster.png          -> no-damage     (conf=0.88)
# socal-fire_00001339_post_disaster.png         -> no-damage     (conf=0.61)
# socal-fire_00001339_pre_disaster.png          -> no-damage     (conf=0.90)
# socal-fire_00001340_post_disaster.png         -> no-damage     (conf=0.89)
# socal-fire_00001340_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001341_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001341_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001343_post_disaster.png         -> destroyed     (conf=0.67)
# socal-fire_00001343_pre_disaster.png          -> no-damage     (conf=0.97)
# socal-fire_00001344_post_disaster.png         -> destroyed     (conf=0.62)
# socal-fire_00001344_pre_disaster.png          -> no-damage     (conf=0.99)
# socal-fire_00001346_post_disaster.png         -> no-damage     (conf=0.62)
# socal-fire_00001346_pre_disaster.png          -> no-damage     (conf=0.86)
# socal-fire_00001347_post_disaster.png         -> no-damage     (conf=0.77)
# socal-fire_00001347_pre_disaster.png          -> no-damage     (conf=0.93)
# socal-fire_00001348_post_disaster.png         -> no-damage     (conf=0.99)
# socal-fire_00001348_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001349_post_disaster.png         -> destroyed     (conf=0.75)
# socal-fire_00001349_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001350_post_disaster.png         -> destroyed     (conf=1.00)
# socal-fire_00001350_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001351_post_disaster.png         -> major-damage  (conf=0.60)
# socal-fire_00001351_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001352_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001352_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001353_post_disaster.png         -> no-damage     (conf=0.59)
# socal-fire_00001353_pre_disaster.png          -> no-damage     (conf=0.96)
# socal-fire_00001354_post_disaster.png         -> no-damage     (conf=0.97)
# socal-fire_00001354_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001355_post_disaster.png         -> no-damage     (conf=0.97)
# socal-fire_00001355_pre_disaster.png          -> no-damage     (conf=0.88)
# socal-fire_00001356_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001356_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001357_post_disaster.png         -> destroyed     (conf=0.83)
# socal-fire_00001357_pre_disaster.png          -> no-damage     (conf=0.98)
# socal-fire_00001359_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001359_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001361_post_disaster.png         -> no-damage     (conf=0.93)
# socal-fire_00001361_pre_disaster.png          -> destroyed     (conf=0.61)
# socal-fire_00001363_post_disaster.png         -> no-damage     (conf=0.60)
# socal-fire_00001363_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001364_post_disaster.png         -> no-damage     (conf=0.86)
# socal-fire_00001364_pre_disaster.png          -> destroyed     (conf=0.81)
# socal-fire_00001365_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001365_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001366_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001366_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001367_post_disaster.png         -> no-damage     (conf=0.99)
# socal-fire_00001367_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001368_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001368_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001369_post_disaster.png         -> destroyed     (conf=0.58)
# socal-fire_00001369_pre_disaster.png          -> no-damage     (conf=0.98)
# socal-fire_00001373_post_disaster.png         -> no-damage     (conf=0.56)
# socal-fire_00001373_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001374_post_disaster.png         -> no-damage     (conf=0.99)
# socal-fire_00001374_pre_disaster.png          -> no-damage     (conf=0.95)
# socal-fire_00001375_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001375_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001376_post_disaster.png         -> destroyed     (conf=0.99)
# socal-fire_00001376_pre_disaster.png          -> no-damage     (conf=0.98)
# socal-fire_00001377_post_disaster.png         -> destroyed     (conf=0.59)
# socal-fire_00001377_pre_disaster.png          -> destroyed     (conf=0.78)
# socal-fire_00001379_post_disaster.png         -> destroyed     (conf=0.98)
# socal-fire_00001379_pre_disaster.png          -> no-damage     (conf=0.94)
# socal-fire_00001380_post_disaster.png         -> no-damage     (conf=0.75)
# socal-fire_00001380_pre_disaster.png          -> no-damage     (conf=0.86)
# socal-fire_00001381_post_disaster.png         -> no-damage     (conf=0.96)
# socal-fire_00001381_pre_disaster.png          -> no-damage     (conf=0.96)
# socal-fire_00001382_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001382_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001383_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001383_pre_disaster.png          -> no-damage     (conf=0.99)
# socal-fire_00001385_post_disaster.png         -> destroyed     (conf=1.00)
# socal-fire_00001385_pre_disaster.png          -> destroyed     (conf=0.92)
# socal-fire_00001386_post_disaster.png         -> destroyed     (conf=1.00)
# socal-fire_00001386_pre_disaster.png          -> destroyed     (conf=0.96)
# socal-fire_00001387_post_disaster.png         -> no-damage     (conf=1.00)
# socal-fire_00001387_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001389_post_disaster.png         -> no-damage     (conf=0.90)
# socal-fire_00001389_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001390_post_disaster.png         -> destroyed     (conf=0.98)
# socal-fire_00001390_pre_disaster.png          -> no-damage     (conf=0.70)
# socal-fire_00001391_post_disaster.png         -> destroyed     (conf=0.92)
# socal-fire_00001391_pre_disaster.png          -> no-damage     (conf=0.99)
# socal-fire_00001394_post_disaster.png         -> destroyed     (conf=0.91)
# socal-fire_00001394_pre_disaster.png          -> no-damage     (conf=0.91)
# socal-fire_00001396_post_disaster.png         -> destroyed     (conf=0.94)
# socal-fire_00001396_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001397_post_disaster.png         -> no-damage     (conf=0.93)
# socal-fire_00001397_pre_disaster.png          -> no-damage     (conf=1.00)
# socal-fire_00001398_post_disaster.png         -> destroyed     (conf=0.90)
# socal-fire_00001398_pre_disaster.png          -> no-damage     (conf=0.99)
# socal-fire_00001399_post_disaster.png         -> no-damage     (conf=0.96)
# socal-fire_00001399_pre_disaster.png          -> no-damage     (conf=0.99)
# socal-fire_00001402_post_disaster.png         -> no-damage     (conf=0.89)
# socal-fire_00001402_pre_disaster.png          -> no-damage     (conf=1.00)
# ✅ Saved 5594/5594 predictions to batch_predictions.csv
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 5
#       2 batch_predict_to_csv()
#       4 # custom folder + quiet mode
# ----> 5 batch_predict_to_csv("some/other/folder", out_csv="preds_other.csv", recursive=True, quiet=True)
#
# Cell In[7], line 18, in batch_predict_to_csv(image_dir, out_csv, recursive, quiet)
#      13 """
#      14 Scan image_dir for images, run inference with the trained checkpoint,
#      15 and save predictions to a CSV with columns: image_path, pred, conf [, error].
#      16 """
#      17 image_dir = Path(image_dir)
# ---> 18 assert image_dir.exists(), f"Directory not found: {image_dir}"
#      20 # Collect paths
#      21 if recursive:
#
# AssertionError: Directory not found: some/other/folder
